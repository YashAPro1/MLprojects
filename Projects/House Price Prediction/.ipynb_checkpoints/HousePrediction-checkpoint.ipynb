# %%
print("Hi there!!")
# Out:
# Hi there!!

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("data.csv")
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.shape
# Out:
# (14620, 23)

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
#Looks like null value will not be problem for us

# %%
import math
df['number of bathrooms'] = df['number of bathrooms'].apply(lambda x: math.ceil(x))

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                    3         3650
# 1  6762810635  42491                   4                    3         2920
# 2  6762810998  42491                   5                    3         2910
# 3  6762812605  42491                   4                    3         3310
# 4  6762812919  42491                   3                    2         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df['number of floors'] = df['number of floors'].apply(lambda x: math.ceil(x))

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                    3         3650
# 1  6762810635  42491                   4                    3         2920
# 2  6762810998  42491                   5                    3         2910
# 3  6762812605  42491                   4                    3         3310
# 4  6762812919  42491                   3                    2         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050                 2                   0                4
# 1      4000                 2                   0                0
# 2      9480                 2                   0                0
# 3     42998                 2                   0                0
# 4      4500                 2                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.457387
# std    6.237575e+03     67.347991            0.938719             0.922707
# min    6.762810e+09  42491.000000            1.000000             1.000000
# 25%    6.762815e+09  42546.000000            3.000000             2.000000
# 50%    6.762821e+09  42600.000000            3.000000             3.000000
# 75%    6.762826e+09  42662.000000            4.000000             3.000000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.551368            0.007661
# std      928.275721  3.791962e+04          0.567758            0.087193
# ...

# %%
df1 = df.drop(["number of floors","number of views","condition of the house","Built Year","Renovation Year","Number of schools nearby","living_area_renov","lot_area_renov","id","Date","waterfront present","grade of the house"],axis='columns')

# %%
df1.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                    3         3650      9050
# 1                   4                    3         2920      4000
# 2                   5                    3         2910      9480
# 3                   4                    3         3310     42998
# 4                   3                    2         2710      4500
#
#    Area of the house(excluding basement)  Area of the basement  Postal Code  \
# 0                                   3370                   280       122003
# 1                                   1910                  1010       122004
# 2                                   2910                     0       122004
# 3                                   3310                     0       122005
# 4                                   1880                   830       122006
#
#    Lattitude  Longitude  Distance from the airport    Price
# ...

# %%
df1.shape
# Out:
# (14620, 11)

# %%
df1.describe()
# Out:
#        number of bedrooms  number of bathrooms   living area      lot area  \
# count        14620.000000         14620.000000  14620.000000  1.462000e+04
# mean             3.379343             2.457387   2098.262996  1.509328e+04
# std              0.938719             0.922707    928.275721  3.791962e+04
# min              1.000000             1.000000    370.000000  5.200000e+02
# 25%              3.000000             2.000000   1440.000000  5.010750e+03
# 50%              3.000000             3.000000   1930.000000  7.620000e+03
# 75%              4.000000             3.000000   2570.000000  1.080000e+04
# max             33.000000             8.000000  13540.000000  1.074218e+06
#
#        Area of the house(excluding basement)  Area of the basement  \
# count                           14620.000000          14620.000000
# mean                             1801.783926            296.479070
# std                               833.809963            448.551409
# ...

# %%
df2 = df1[~(df1['living area']/df1["number of bedrooms"]<300)]

# %%
df2
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                    3         3650      9050
# 1                       4                    3         2920      4000
# 2                       5                    3         2910      9480
# 3                       4                    3         3310     42998
# 4                       3                    2         2710      4500
# ...                   ...                  ...          ...       ...
# 14614                   3                    2         1590      7931
# 14615                   2                    2         1556     20000
# 14616                   3                    2         1680      7000
# 14617                   2                    1         1070      6120
# 14619                   3                    1          900      4770
#
#        Area of the house(excluding basement)  Area of the basement  \
# ...

# %%
df2["number of bathrooms"].describe()
# Out:
# count    14485.000000
# mean         2.467656
# std          0.918980
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          3.000000
# max          8.000000
# Name: number of bathrooms, dtype: float64

# %%
df2[df2["number of bathrooms"]>6]
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 76                      7                    8        13540    307752
# 418                     5                    7         7270    130017
# 2425                    5                    7         8670     64033
# 2794                    5                    7         9640     13068
# 4061                    5                    7         8020     21738
# 6730                    9                    8         4050      6504
# 9171                    6                    8         9890     31374
# 10177                   7                    7         7480     41664
# 10503                   6                    8        12050     27600
#
#        Area of the house(excluding basement)  Area of the basement  \
# 76                                      9410                  4130
# 418                                     6420                   850
# ...

# %%
def remove_outliers(df):
    for index,x in df.iterrows():
        if x["number of bathrooms"]>x["number of bedrooms"]+1:
            df.drop(index,inplace=True)
    return df

# %%
remove_outliers(df2)
# Out:
# C:\Users\Yashkumar Dubey\AppData\Local\Temp\ipykernel_11064\2034404030.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index,inplace=True)
# C:\Users\Yashkumar Dubey\AppData\Local\Temp\ipykernel_11064\2034404030.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index,inplace=True)
# C:\Users\Yashkumar Dubey\AppData\Local\Temp\ipykernel_11064\2034404030.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
count = 0
for x in df.index:
    if df["number of bathrooms"][x]>df["number of bedrooms"][x]+1:
        count += 1
print(count)
# Out:
# 33

# %%
df3 = df2.copy()

# %%
df3.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                    3         3650      9050
# 1                   4                    3         2920      4000
# 2                   5                    3         2910      9480
# 3                   4                    3         3310     42998
# 4                   3                    2         2710      4500
#
#    Area of the house(excluding basement)  Area of the basement  Postal Code  \
# 0                                   3370                   280       122003
# 1                                   1910                  1010       122004
# 2                                   2910                     0       122004
# 3                                   3310                     0       122005
# 4                                   1880                   830       122006
#
#    Lattitude  Longitude  Distance from the airport    Price
# ...

# %%
df3.describe()
# Out:
#        number of bedrooms  number of bathrooms   living area      lot area  \
# count        14452.000000         14452.000000  14452.000000  1.445200e+04
# mean             3.374066             2.461389   2101.868600  1.509712e+04
# std              0.900019             0.908043    908.472928  3.798239e+04
# min              1.000000             1.000000    370.000000  5.200000e+02
# 25%              3.000000             2.000000   1450.000000  5.001750e+03
# 50%              3.000000             3.000000   1940.000000  7.620000e+03
# 75%              4.000000             3.000000   2578.500000  1.080000e+04
# max             10.000000             8.000000  13540.000000  1.074218e+06
#
#        Area of the house(excluding basement)  Area of the basement  \
# count                           14452.000000          14452.000000
# mean                             1804.598049            297.270551
# std                               821.270504            446.425442
# ...

# %%
X = df3.drop('Price',axis="columns")

# %%
y= df3.Price

# %%
X.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                    3         3650      9050
# 1                   4                    3         2920      4000
# 2                   5                    3         2910      9480
# 3                   4                    3         3310     42998
# 4                   3                    2         2710      4500
#
#    Area of the house(excluding basement)  Area of the basement  Postal Code  \
# 0                                   3370                   280       122003
# 1                                   1910                  1010       122004
# 2                                   2910                     0       122004
# 3                                   3310                     0       122005
# 4                                   1880                   830       122006
#
#    Lattitude  Longitude  Distance from the airport
# 0    52.8645   -114.557                         58
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_scaled = scaler.fit_transform(X)

# %%
y.head()
# Out:
# 0    2380000
# 1    1400000
# 2    1200000
# 3     838000
# 4     805000
# Name: Price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X_train,X_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.3,random_state=10)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.5745235910292017

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

# %%
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(),X,y,cv=cv)
# Out:
# array([0.59223615, 0.58478845, 0.59272745, 0.60953461, 0.59165495])

# %%
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
def fin_best_model(X,y):
    algos = {
        'linear_regression':{
            'model':LinearRegression(),
            'params':{
                'normalize':[True, False]
            }
        },
        'lasso':{
            'model':Lasso(),
            'params':{
                'alpha':[1,2],
                'selection':['random', 'cyclic']
            }
        },
        'decision_tree':{
            'model':DecisionTreeRegressor(),
            'params':{
                'criterion':['mse', 'friedman_mse'],
                'splitter': ['best','random']
            }
        },
#         'svm':{
#             'model':SVC(),
#             'params':{
#                 'C': [1, 10, 100], 
#                 'gamma': [1, 0.1, 0.01],
#                 'kernel': ['rbf']
#             }
#         },
#         'random_classifier':{
#             'model':RandomForestClassifier(),
#             'params':{
#                 'n_estimators': [200, 500],
#                 'max_features': ['auto', 'sqrt', 'log2'],
#                 'max_depth' : [4,5,6,7,8],
#                 'criterion' :['gini', 'entropy']
#             }
#         }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs = GridSearchCV(config['model'],config['params'],cv = cv ,return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model':algo_name,
            'best_score':gs.best_score_,
            'best_params':gs.best_params_
        })
    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

# %%
fin_best_model(x_scaled,y)
# Out:
# C:\Users\Yashkumar Dubey\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\Users\Yashkumar Dubey\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# ...

# %%
dr_clf = DecisionTreeRegressor()
dr_clf.fit(X_train,y_train)
dr_clf.score(X_test,y_test)
# Out:
# 0.5650040284378771

# %%
def predict_price(bhk,bath,living,areaoh,areaob,postc,lat,lon,distoa):    
#     loc_index = np.where(X.columns==location)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = bhk
    x[1] = bath
    x[2] = living
    x[3] = areaoh
    x[4] = areaob
    x[5] = postc
    x[6] = lat
    x[7] = lon
    x[8] = distoa
   

    return dr_clf.predict([x])[0]

# %%
predict_price(7,3,5650,2370,280,500,52.8745,-114.557,58)
# Out:
# 7060000.0
